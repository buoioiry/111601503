# %% [markdown]
# 在這次的作業二中，我選擇了老師推薦的spaceship titanic，這個比賽的預測和上課所學之鐵達尼號預測過程較相近，故我決定將鐵達尼號預測之程式碼作為基礎，進行修改以搭配spaceship titanic的變數。
#
# 整個過程主要參考講義之介紹和上課更正完成的程式碼修改，將不確定的程式碼複製到chatgpt，透過其解釋函數定義和用法，接下來再根據csv檔中資料更改變數反覆測試，使我得以複習並重新理解上課內容，同時進一步理解實際應用。
#
# spaceship titanic的比賽故事背景為一發生意外之鐵達尼號太空船，我們需透過其殘缺資料預測哪些乘客已經被傳送離開。最終測試之結果如下圖所示，我的預測準確率為0.60088，推測可能原因為VIP、destination 、Homeplanet的資料填補上採用極大值，若改以中位數或平均值填補有可能提高準確度，亦有可能是此題較為適合保留其他變數計算或增加保留變數，以提高模型的預測性能。

# %% [markdown]
# ![image.png](attachment:image.png)
